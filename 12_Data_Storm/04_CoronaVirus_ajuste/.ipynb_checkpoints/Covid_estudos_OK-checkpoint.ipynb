# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Fonte: https://ourworldindata.org/coronavirus-source-data

# %% [markdown]
# ### Dados Bruto

# %%
df = pd.read_csv('./owid-covid-data.csv')

# %%
#Mostrar todas as Colunas
pd.set_option('display.max_columns',df.shape[1]+1)
#Mostrar todas as Linhas
pd.set_option('display.max_rows',df.shape[0]+1)

# %%
df.head(2)
# Out:
#   iso_code location        date  total_cases  new_cases  total_deaths  \
# 0      ABW    Aruba  2020-03-13            2          2             0
# 1      ABW    Aruba  2020-03-20            4          2             0
#
#    new_deaths  total_cases_per_million  new_cases_per_million  \
# 0           0                   18.733                 18.733
# 1           0                   37.465                 18.733
#
#    total_deaths_per_million  new_deaths_per_million  total_tests  new_tests  \
# 0                       0.0                     0.0          NaN        NaN
# 1                       0.0                     0.0          NaN        NaN
#
#    total_tests_per_thousand  new_tests_per_thousand tests_units  population  \
# 0                       NaN                     NaN         NaN    106766.0
# 1                       NaN                     NaN         NaN    106766.0
#
#    population_density  median_age  aged_65_older  aged_70_older  \
# 0               584.8        41.2         13.085          7.452
# 1               584.8        41.2         13.085          7.452
#
#    gdp_per_capita  extreme_poverty  cvd_death_rate  diabetes_prevalence  \
# 0       35973.781              NaN             NaN                11.62
# 1       35973.781              NaN             NaN                11.62
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                     NaN
# 1             NaN           NaN                     NaN
#
#    hospital_beds_per_100k
# 0                     NaN
# 1                     NaN

# %% [markdown]
# ### Total de Mortes

# %%
total_mortes = df.groupby(df['location'])['new_deaths'].sum()
total_casos = df.groupby(df['location'])['new_cases'].sum()

# %%
#Selecionei algusn países
paises = ['Brazil','United States','Italy','China','United Kingdom']
#Gráficos
total_mortes[paises].sort_values(ascending=True).plot.bar()
plt.xlabel('')
# Out:
# Text(0.5, 0, '')

# %%
total_casos[paises].sort_values(ascending=True).plot.bar()
plt.xlabel('')
# Out:
# Text(0.5, 0, '')

# %%
total = pd.DataFrame()
total['mortes'] = total_mortes
total['casos'] = total_casos
total.head()
# Out:
#              mortes  casos
# location
# Afghanistan     115   4033
# Albania          31    856
# Algeria         494   5558
# Andorra          48    754
# Angola            2     43

# %%
total = total.loc[paises]
total
# Out:
#                 mortes    casos
# location
# Brazil           10627   155939
# United States    78794  1309541
# Italy            30395   218268
# China             4637    83991
# United Kingdom   31587   215260

# %%
total = total[['mortes','casos']].apply(selecionar,axis=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-123-233f75c1ac53> in <module>
# ----> 1 total = total[['mortes','casos']].apply(selecionar,axis=1)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6485                          args=args,
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#    6489     def applymap(self, func):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# --> 151         return self.apply_standard()
#     152
#     153     def apply_empty_result(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in apply_standard(self)
#     255
#     256         # compute the result using the series generator
# --> 257         self.apply_series_generator()
#     258
#     259         # wrap results
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#     284             try:
#     285                 for i, v in enumerate(series_gen):
# --> 286                     results[i] = self.f(v)
#     287                     keys.append(v.name)
#     288             except Exception as e:
#
# <ipython-input-122-90f99a7d0c0c> in selecionar(x)
#       3 def selecionar(x):
#       4
# ----> 5     if x in paises:
#       6         return x
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1477         raise ValueError("The truth value of a {0} is ambiguous. "
#    1478                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1479                          .format(self.__class__.__name__))
#    1480
#    1481     __bool__ = __nonzero__
#
# ValueError: ('The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().', 'occurred at index Afghanistan')

# %%
sns.barplot(y = total['mortes'][paises],data = total)

# %%
total_new = total[if total.index in paises]
# Out:
#   File "<ipython-input-85-63fffe38ed76>", line 1
#     total_new = total[if total.index in paises]
#                        ^
# SyntaxError: invalid syntax

# %%
sns.barplot(x = total.index[paises],y = total['mortes'][paises],data = total,hue = 'casos')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py:3968: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = getitem(key)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-81-ba731c5a5949> in <module>
# ----> 1 sns.barplot(x = total.index[paises],y = total['mortes'][paises],data = total,hue = 'casos')
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    3966
#    3967         key = com.values_from_object(key)
# -> 3968         result = getitem(key)
#    3969         if not is_scalar(result):
#    3970             return promote(result)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
total_mortes = df.groupby(df['location'])['new_deaths'].sum()
total_mortes[paises].sort_values(ascending=True).plot.bar()
plt.xlabel('')
# Out:
# Text(0.5, 0, '')

# %%
df_new = df[df['location'] == 'Brazil'].reset_index().drop('index',axis=1)

# %%
df_new  = df_new[['date','total_cases','total_deaths']]

# %%
df_new.tail()
# Out:
#            date  total_cases  total_deaths
# 127  2020-05-06       114715          7921
# 128  2020-05-07       125218          8536
# 129  2020-05-08       135106          9146
# 130  2020-05-09       145328          9897
# 131  2020-05-10       155939         10627

# %% [markdown]
# ### obs: Estilo Seaborn você pode usar no matplotlib
# plt.style.use('seaborn')

# %%
# Plote-date
plt.style.use('seaborn')

# %%
df_new.plot(x = 'date', y = ['total_cases','total_deaths'])
#plt.xticks(np.arange(0,df_new.shape[0],step = 30),rotation=20)
plt.xticks(rotation=20)

plt.xlabel('')
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# ### Converter para Datetime

# %%
df_new.info()
#Não reconheceu a coluna date como arquivo de Data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 3 columns):
# date            132 non-null object
# total_cases     132 non-null int64
# total_deaths    132 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 3.2+ KB

# %%
df_new['date'] = pd.to_datetime(df_new['date'],format = '%Y/%m/%d')#formato que está

# %%
df_new.info()
#Agora está como datetime64 (ok)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 3 columns):
# date            132 non-null datetime64[ns]
# total_cases     132 non-null int64
# total_deaths    132 non-null int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 3.2 KB

# %%
#plt.figure(figsize=(10,8))
#plt.plot(df_new['date'],df_new['total_cases'])
df_new.plot(x= 'date')

#Veja a Diferença no plot

# %%
sns.regplot(x='total_deaths', y="total_cases", data=df_new)

# %%
df_new.shape[0]
# Out:
# 132

# %% [markdown]
# #### testando regplot

# %%
x = np.arange(0,100)
y = x**4

sns.regplot(x=x,y=y, n_boot=1000,order=2,label='Real')
plt.legend()

# %%
sns.regplot(x=np.arange(0,df_new.shape[0]),y=df_new['total_cases'], n_boot=10,order=2,label='132 days of covid-19')
plt.legend()

# %%
p = sns.regplot(x=np.arange(70,df_new.shape[0]),y=df_new['total_cases'][70:], n_boot=10,order=2,label='132 days of covid-19')
plt.legend()

# %%
#Agora como ele reconhece como date a nossa 
#coluna date, podemos executar algumas funções

# %%
#Mês
df_new['date'].dt.month.head(3)
# Out:
# 0    12
# 1     1
# 2     1
# Name: date, dtype: int64

# %%
#dia
df_new['date'].dt.day.head(3)
# Out:
# 0    31
# 1     1
# 2     2
# Name: date, dtype: int64

# %%
#Ano
df_new['date'].dt.year.head(3)
# Out:
# 0    2019
# 1    2020
# 2    2020
# Name: date, dtype: int64

# %%
#Agrupamentode infectados por mês
mes = df_new.groupby(df_new['date'].dt.month)['total_cases'].sum()

# %%
mes
# Out:
# date
# 1           34
# 2          665
# 3       925940
# 4     18695034
# 5     11928871
# 12           0
# Name: total_cases, dtype: int64

# %%
mes[0:5].plot.bar()
