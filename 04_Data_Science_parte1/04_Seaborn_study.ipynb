# %% [markdown]
# # Seaborn (complementar do Matplotlib)
#
# - Utiliza-se dos recursos da matplotlib. <br>
# - Relaciona-se fácil com o Pandas <br>
# - Seaborn, which provides a high-level interface to draw statistical graphics.<br>
#
# fonte: https://www.datacamp.com/community/tutorials/seaborn-python-tutorial?utm_source=adwords_ppc&utm_campaignid=1455363063&utm_adgroupid=65083631748&utm_device=c&utm_keyword=&utm_matchtype=b&utm_network=g&utm_adpostion=&utm_creative=332602034358&utm_targetid=dsa-473406580275&utm_loc_interest_ms=&utm_loc_physical_ms=1001778&gclid=Cj0KCQjwmdzzBRC7ARIsANdqRRltSPqpRLhBTRHAR81XbU7LmiIo0uNPnLj5MONHOZiwO-NP9nJ6wI0aAozWEALw_wcB#sm

# %% [markdown]
# ### Parte 1 - Distribution Plots

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head(4)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2

# %%
tips['sex']

h = 0
m = 0

for i in range(0,len(tips['sex'])):
    if tips['sex'][i] == 'Male':
        h = h + 1
    else:
        m = m + 1
print(
    'mulher: %3.0f\n'%m,
    'homem: %3.0f\n'%h,
    'total: %3.0f'%(h+m)
)
# Out:
# mulher:  87
#  homem: 157
#  total: 244

# %% [markdown]
# ## KDE - Kernel Densitu Estimate (Estimativa de densidade kernel)
#
# - consiste em pegar os histogramas e criar uma gaussiana para cada, depois somar todas gaussianas

# %%
#Estilo
plt.figure(figsize = (8,5))

sns.set_style(
    'darkgrid'
)

sns.distplot(
    a = tips['total_bill'],
    #kde = False, #Curva (Kernel Density Estimate)
    #hist = False, #Histograma
    label = 'Estimativa de densidade de Kernel',
    #rug = True,
    
)
plt.legend()
plt.savefig('./graficos/A');

# %%
tips['total_bill'].mean()
# Out:
# 19.78594262295082

# %%
plt.figure(figsize = (8,5))
sns.distplot(tips['total_bill'],kde = False,color = 'red')
plt.savefig('./graficos/B');

# %%
sns.distplot(
    tips['total_bill'],
    bins = 40 #Quantidade de separador
)
#quantidade de histogramas

# %%
sns.jointplot(x='total_bill',y='tip',data=tips, color = 'green')
plt.savefig('./graficos/C');

# %%
sns.jointplot(x='total_bill',y='tip',data=tips, kind ='hex', color = 'green');
plt.savefig('./graficos/D');

# %%
sns.jointplot(x='total_bill',y='tip',data=tips, kind ='reg', color = "green")
plt.savefig('./graficos/E');

# %%
sns.jointplot(x='total_bill',y='tip',data=tips, kind ='kde', color = "green")
plt.savefig('./graficos/F');

# %%
sns.pairplot(tips, hue = 'sex')
plt.savefig('./graficos/G');

# %%
data1 = {
    'idade':[1,2.5,6,11,5.5,1.5,2,20,30],
    'gasto':[40,30,20,10,1,1,10,10,15]
}

df = pd.DataFrame(data = data1)
sns.distplot(df['idade'])

# %%
sns.jointplot(x='gasto',y='idade',data=data1, kind ='kde' )
plt.savefig('./graficos/H');

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
tips['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
# 5      25.29
# 6       8.77
# 7      26.88
# 8      15.04
# 9      14.78
# 10     10.27
# 11     35.26
# 12     15.42
# 13     18.43
# 14     14.83
# 15     21.58
# 16     10.33
# 17     16.29
# 18     16.97
# 19     20.65
# 20     17.92
# 21     20.29
# 22     15.77
# 23     39.42
# 24     19.82
# 25     17.81
# 26     13.37
# 27     12.69
# 28     21.70
# 29     19.65
#        ...
# 214    28.17
# 215    12.90
# 216    28.15
# 217    11.59
# 218     7.74
# 219    30.14
# 220    12.16
# 221    13.42
# 222     8.58
# 223    15.98
# 224    13.42
# 225    16.27
# 226    10.09
# 227    20.45
# 228    13.28
# 229    22.12
# 230    24.01
# 231    15.69
# 232    11.61
# 233    10.77
# 234    15.53
# 235    10.07
# 236    12.60
# 237    32.83
# 238    35.83
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
sns.pairplot(tips)
plt.savefig('./graficos/I');

# %%
sns.pairplot(
    data = tips,
    hue = 'sex',#Argumento para COMPARAR   
)

# %%
sns.pairplot(tips, hue = 'time')

# %%
sns.pairplot(tips, hue = 'day',palette = 'coolwarm' )

# %%
sns.rugplot(tips['total_bill'])

# %%
sns.distplot(tips['total_bill'],kde = False)

# %%
#help(pd.read_csv) #usei pra ver como separar por Tab... pois o padrão é ','
df1 = pd.read_csv('./dados_panda/multicamada.txt',sep = '\t')
df1.head()
# Out:
#    Freq (GHZ)  RL(dB)
# 0       12.40   -8.14
# 1       12.40   -8.04
# 2       12.41   -8.25
# 3       12.41   -8.31
# 4       12.41   -8.34

# %%
sns.distplot(df1['RL(dB)'], );
plt.savefig('./graficos/J')

# %%
sns.distplot(df1['Freq (GHZ)'], )

# %%
sns.jointplot(x='Freq (GHZ)',y='RL(dB)',data=df1, kind ='kde' )

# %% [markdown]
# ### Parte 2 - Categorical Plots

# %%
import seaborn as sns
import numpy as np
# %matplotlib inline
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x='sex',y='total_bill',data= tips)

# %%
#func desvio padrao
sns.barplot(x='sex',y='total_bill',data= tips,estimator = np.std)

# %%
sns.countplot(x='sex',data = tips)

# %%
sns.countplot(x='day',data = tips)
plt.savefig('./graficos/K');

# %%
sns.boxplot(x='day', y ='total_bill', data = tips)
plt.savefig('./graficos/L');

# %%
sns.boxplot(x='day', y ='total_bill', data = tips, hue = 'smoker')
plt.savefig('./graficos/L');

# %%
sns.violinplot(x='day',y = 'total_bill',data = tips)
plt.savefig('./graficos/M');

# %%
sns.violinplot(x='day',y = 'total_bill',data = tips,hue = 'sex')
plt.savefig('./graficos/N');

# %%
sns.violinplot(x='day',y = 'total_bill',data = tips,hue = 'sex', split = True)

# %%
sns.stripplot(x = 'day', y = 'total_bill', data = tips)

# %%
sns.stripplot(x = 'day', y = 'total_bill', data = tips, jitter = True)

# %%
sns.stripplot(x = 'day', y = 'total_bill', data = tips, jitter = False)

# %%
sns.stripplot(x = 'day', y = 'total_bill', data = tips, jitter = True, hue = 'sex')

# %%
sns.stripplot(
    x = 'day',
    y = 'total_bill',
    data = tips,
    jitter = True,
    hue = 'sex',
    #split = True, #Mudou para dodge
    dodge = True,
)

# %%
sns.swarmplot(x = 'day', y = 'total_bill', data = tips)

# %%
sns.violinplot(x = 'day' , y = 'total_bill', data = tips)
sns.swarmplot(x = 'day', y = 'total_bill', data = tips, color = 'black')

# %%
# Mudaram o nome da funcao de factorplot para catplot
#sns.factorplot(x = 'day', y = 'total_bill' , data = tips, kind = 'bar')
sns.catplot(x = 'day', y = 'total_bill' , data = tips, kind = 'bar')

# %%
sns.catplot(x = 'day', y = 'total_bill' , data = tips, kind = 'violin')

# %% [markdown]
# ### Parte 3 - Matrix Plots

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Dados de correlação
tc = tips.corr()

# %%
sns.heatmap(tc)

# %%
#argumento
sns.heatmap(tc, annot = True)
plt.savefig('./graficos/O');

# %%
sns.heatmap(tc, annot = True, cmap = 'coolwarm')

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
fp = flights.pivot_table(index = 'month', columns = 'year', values = 'passengers')
fp.head()
# Out:
# year      1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January    112   115   145   171   196   204   242   284   315   340   360
# February   118   126   150   180   196   188   233   277   301   318   342
# March      132   141   178   193   236   235   267   317   356   362   406
# April      129   135   163   181   235   227   269   313   348   348   396
# May        121   125   172   183   229   234   270   318   355   363   420
#
# year      1960
# month
# January    417
# February   391
# March      419
# April      461
# May        472

# %%
sns.heatmap(fp, cmap = 'magma')
plt.savefig('./graficos/P');

# %%
sns.heatmap(fp, cmap = 'magma', linecolor = 'white', linewidth = '1')
plt.savefig('./graficos/Q');

# %%
sns.clustermap(fp, cmap = 'coolwarm')
#Repare que ele reorganiza
plt.savefig('./graficos/R');

# %%
sns.clustermap(fp, cmap = 'coolwarm', standard_scale=1)
#Repare que ele reorganiza

# %% [markdown]
# ### Parte 3 - Grids

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
g = sns.PairGrid(iris)
g.map(plt.scatter)

# %%
g = sns.PairGrid(iris)

#Plotar Mapas na Diagonais
g.map_diag(sns.distplot)

#Plotar Mapas superior
g.map_upper(plt.scatter)

#Plotar Mapas Inferiores
g.map_lower(sns.kdeplot)

plt.savefig('./graficos/S');

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
h = sns.FacetGrid(data = tips, hue= 'sex',col = 'time', row='smoker')
h.map(sns.distplot,'total_bill')

# %%
h = sns.FacetGrid(data = tips, hue= 'sex',col = 'time', row='smoker')

h.map(sns.distplot,'tip')
#plt.savefig('./teste.png')]
plt.savefig('./graficos/T');

# %% [markdown]
# ### Parte 4 - Regression Plots

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x='total_bill', y='tip', data = tips )
plt.savefig('./graficos/U');

# %%
#hue = comparar
sns.lmplot(
    x='total_bill',
    y='tip',
    data = tips,
    hue ='sex',#Compara
    markers = ['*','v'],#Muda o plot
    scatter_kws = {'s':150}#Aumenta o tamanho
)
plt.savefig('./graficos/V');

# %%
sns.lmplot(
    x='total_bill',
    y='tip',
    data = tips,
    col = 'day',
    #row='time',
    hue = 'sex',
    aspect = 0.6,
    #size =8 #mudou o nome pra height
    height = 8,   
)
#plt.savefig('./teste.png')

# %% [markdown]
# ### Parte 5 - Style and Color

# %%
#Estilo
sns.set_style(
    style='darkgrid',#darkgrid, whitegrid, dark, white, ticks        
)
sns.countplot(
    x = 'sex',
    data = tips
)

# %%
#Estilo
sns.set_style(
    style='ticks',#darkgrid, whitegrid, dark, white, ticks        
)
sns.countplot(
    x = 'sex',
    data = tips
)

sns.despine()#Remove os eixos

# %%
plt.figure(
    figsize = (12,3),
)


sns.countplot(
    x = 'sex',
    data = tips
)

# %%
"""sns.set_context(
    context = 'poster',
    font_scale= 1
)"""

sns.countplot(
    x = 'sex',
    data = tips
)
